# %% [markdown]
# Olá, Jules
#
# Meu nome é Ramon. Fico feliz em revisar seu projeto. Ao ao longo do texto farei algumas observações sobre melhorias no código e também farei comentários sobre suas percepções sobre o assunto. Estarei aberto a feedbacks e discussões sobre o tema.
#
# **Peço que mantenha e não altere os comentários que eu fizer por aqui para que possamos nos localizar posteriormente, ok?**
#
# Mais uma coisa, vamos utilizar um código de cores para você entender os meus feedbacks no seu notebook. Funciona assim:
#
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Sucesso. Tudo foi feito corretamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Alerta não crítco, mas que pode ser corrigido para melhoria geral no seu código/análise
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Erro que precisa ser consertado, caso contrário seu projeto **não** será aceito.
# </div>
#
# Você pode me responder usando isso:
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# </div>
#
# ###
#
# <div class="alert alert-block alert-success">
# <b>Comentário Geral do Revisor</b> <a class="tocSkip"></a>
#
# Obrigado por enviar seu projeto.
#
# Parabéns, você fez um bom trabalho.
#
# Como pontos fortes do projeto, destaco:
# - Código simples e eficiente (sem loop desnecessário)
# - Uso adequado dos recursos da lição
# - Você tem boa lógica de programação
#
# <span class="text-danger">Porém, há espaço para melhorias conforme os itens apontados anteriormente. Destaco os  pontos a seguir: </span>
#  * <span class="text-danger"> Há algumas questões que precisam de ajustes, sobretudo na segunda parte. São coisas pequenas.  </span>
#
#
# Portanto, sugiro que você corrija os pontos indicados.
#
# Se você tiver alguma dúvida sobre de algo que você não tenha entendido, sinta-se à vontade para perguntar ao tutor ou deixar um comentário em **azul** para que, na próxima iteração, eu possa responder.
#
# Conte conosco. Lembre-se de que você pode tirar dúvidas com revisores usando os comentários ou buscar ajuda de um tutor.
# Bom trabalho.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário final do revisor: </b> <a class="tocSkip"></a>
#
# Tudo certo agora. Desejo sucesso na jornada. Parabéns pelo empenho.
# </div>

# %% [markdown]
# # Vamos encher o carrinho!

# %% [markdown]
# # Introdução
#
# O Instacart é uma plataforma de entrega de supermercado onde os clientes podem fazer um pedido no supermercado e depois receber sua compra, semelhante ao funcionamento do Uber Eats e do iFood. O conjunto de dados que fornecemos foi modificado a partir do original. Reduzimos o tamanho dele para que seus cálculos sejam executados mais rapidamente e incluímos valores ausentes e duplicados. Também tivemos o cuidado de preservar as distribuições dos dados originais quando fizemos as alterações.
#
# Você precisa completar três etapas. Para cada uma delas, escreva uma breve introdução descrevendo como você pretende concluir a etapa e justifique suas decisões em parágrafos explicativos a medida que você avança na solução. Escreva também uma conclusão para resumir suas conclusões e escolhas.

# %% [markdown]
# ## Dicionário de dados
#
# Há cinco tabelas no conjunto de dados, e você vai precisar usar todas elas para pré-processar seus dados e fazer AED. Abaixo está um dicionário que lista as colunas de cada tabela e descreve os dados contidos nelas.
#
# - `instacart_orders.csv`: cada linha corresponde a um pedido no aplicativo da Instacart
#     - `'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     - `'user_id'`: é o número de identificação exclusivo da conta de cada cliente
#     - `'order_number'`: é o número de vezes que o cliente fez um pedido
#     - `'order_dow'`: é o dia da semana em que o pedido foi feito (0 é domingo)
#     - `'order_hour_of_day'`: é a hora do dia em que o pedido foi feito
#     - `'days_since_prior_order'`: é o número de dias desde que o cliente fez seu pedido anterior
#
#
#
#
# - `products.csv`: cada linha corresponde a um produto exclusivo que os clientes podem comprar
#     - `'product_id'`: é o número de identificação unívoco de cada produto
#     - `'product_name'`: é o nome do produto
#     - `'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     - `'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#
#
#
#
# -	`order_products.csv`: cada linha corresponde a um item incluído em um pedido
#     -	`'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     -	`'product_id'`: é o número de identificação exclusivo de cada produto
#     -	`'add_to_cart_order'`: é a ordem sequencial em que cada item foi colocado no carrinho
#     -	`'reordered'`: 0 se o cliente nunca comprou o produto antes, 1 se já o comprou
#
#
#
#
# -	`aisles.csv`
#     -	`'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     -	`'aisle'`: é o nome do corredor
#
#
#
# -	`departments.csv`
#     -	`'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#     -	`'department'`: é o nome do departamento

# %% [markdown]
# # Etapa 1. Visão geral dos dados
#
# Leia os arquivos de dados (/datasets/instacart_orders.csv, /datasets/products.csv, /datasets/aisles.csv, /datasets/departments.csv e /datasets/order_products.csv) com `pd.read_csv()` usando os parâmetros apropriados para fazer isso corretamente. Verifique as informações para cada DataFrame criado.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Visão geral dos dados

# %%
# Importe as bibliotecas
import pandas as pd
import numpy as np

# %%
# leia os conjuntos de dados em DataFrames


orders = pd.read_csv('/datasets/instacart_orders.csv',sep=';')

products = pd.read_csv('/datasets/products.csv',sep=';')

order_products = pd.read_csv('/datasets/order_products.csv',sep=';')

aisles = pd.read_csv('/datasets/aisles.csv',sep=';')

departments = pd.read_csv('/datasets/departments.csv',sep=';')


orders['order_id'] = orders['order_id'].astype('int64')
orders['user_id'] = orders['user_id'].astype('int64')
products['product_id'] = products['product_id'].astype('int64')
products['aisle_id'] = products['aisle_id'].astype('int64')
products['department_id'] = products['department_id'].astype('int64')
order_products['order_id'] = order_products['order_id'].astype('int64')
order_products['product_id'] = order_products['product_id'].astype('int64')
aisles['aisle_id'] = aisles['aisle_id'].astype('int64')
departments['department_id'] = departments['department_id'].astype('int64')

# %%
# imprima as informações sobre o DataFrame
print("Informações sobre pedidos (orders):")
print(f"- Total de registros: {len(orders)}")
print(f"- Colunas disponíveis: {list(orders.columns)}")
print(f"- Exemplo de dados:\n{orders.head(2)}")
orders['days_since_prior_order'] = orders['days_since_prior_order'].fillna(0)
print(f"- Valores ausentes:\n{orders.isna().sum()}")
print(f"- Duplicados: {orders.duplicated().sum()}")
orders = orders.drop_duplicates()
# Out:
# Informações sobre pedidos (orders):
# - Total de registros: 478967
# - Colunas disponíveis: ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']
# - Exemplo de dados:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# - Valores ausentes:
# order_id                  0
# user_id                   0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64
# - Duplicados: 15

# %%
# imprima as informações sobre o DataFrame
print("\nInformações sobre produtos (products):")
print(f"- Total de produtos únicos: {len(products)}")
print(f"- Informações: {products.info()}")
print(f"- Duplicados: {products.duplicated().sum()}")
products = products.drop_duplicates()
# Out:
# Informações sobre produtos (products):
# - Total de produtos únicos: 49694
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# - Informações: None
# - Duplicados: 0

# %%
# imprima as informações sobre o DataFrame


print(order_products['add_to_cart_order'].isna().sum())

order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(0)


print("\nInformações sobre produtos por pedido (order_products):")
print(f"- Total de itens pedidos: {len(order_products)}")
print(f"- Informações: {order_products.info()}")
print(f"- Duplicados: {order_products.duplicated().sum()}")
order_products = order_products.drop_duplicates()
# Out:
# 836
#
# Informações sobre produtos por pedido (order_products):
# - Total de itens pedidos: 4545007
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# - Informações: None
# - Duplicados: 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Não é correto usar drpona(). Tive de comentar
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %%
# imprima as informações sobre o DataFrame
print("\nInformações sobre corredores (aisles):")
print(f"- Total de corredores: {len(aisles)}")
print(f"-Informações:\n{aisles.info()}")
print(f"- Duplicados: {aisles.duplicated().sum()}")
aisles = aisles.drop_duplicates()
# Out:
# Informações sobre corredores (aisles):
# - Total de corredores: 134
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# -Informações:
# None
# - Duplicados: 0

# %%
# imprima as informações sobre o DataFrame


print("\nInformações sobre departamentos (departments):")
print(f"- Total de departamentos: {len(departments)}")
print(f"- Informções:\n{departments.info()}")
print(f"- Duplicados: {departments.duplicated().sum()}")
departments = departments.drop_duplicates()
# Out:
# Informações sobre departamentos (departments):
# - Total de departamentos: 21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
# - Informções:
# None
# - Duplicados: 0

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 1. Visão geral dos dados
#
# Esta etapa inicial foi crucial para identificar a estrutura dos dados e os principais problemas que precisam ser resolvidos antes de prosseguir com análises mais avançadas, como correção do parâmetro sep=';', e dos valores ausentes.

# %% [markdown]
# # Etapa 2. Preparação de dados
#
# Faça o pré-processamento dos dados da seguinte maneira:
#
# -	Verifique e corrija os tipos de dados (por exemplo, certifique-se de que as colunas de ID sejam números inteiros)
# -	Identifique e preencha valores ausentes
# -	Identifique e remova valores duplicados
#
# Certifique-se de explicar que tipos de valores ausentes e duplicados você encontrou, como você os preencheu ou removeu, por que escolheu esses métodos e por que você acha que esses valores ausentes e duplicados estavam presentes no conjunto de dados.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Preparação de dados           Para a Etapa 2, o plano de preparação de dados consiste em corrigir os tipos de dados, garantindo que identificadores numéricos estejam no formato int64, além de identificar e preencher valores ausentes de maneira apropriada, como preencher days_since_prior_order e add_to_cart_order com zero. Também é necessário localizar e remover registros duplicados para garantir a integridade dos dados.

# %% [markdown]
# ## Encontre e remova valores duplicados (e descreva por que você está fazendo suas escolhas)

# %% [markdown]
# ### DataFrame `instacart_orders`

# %%
# Verificar se há pedidos duplicados
print("Pedidos totalmente duplicados:", orders.duplicated().sum())
# Out:
# Pedidos totalmente duplicados: 0

# %% [markdown]
# Há linhas duplicadas? Se sim, o que elas têm em comum? Indica que o mesmo pedido foi registrado mais de uma vez sem qualquer alteração nas informações

# %%
# Com base nas suas conclusões,

# verifique todos os pedidos feitos às 2h da manhã nas quartas-feiras
wed_2am_orders = orders[(orders['order_hour_of_day'] == 2) & (orders['order_dow'] == 3)]
print("\nPedidos às 2h da manhã nas quartas-feiras:\n", wed_2am_orders)
# Out:
# Pedidos às 2h da manhã nas quartas-feiras:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# ...

# %% [markdown]
# O que esse resultado quer dizer? Foram encontrados 106 pedidos feitos às 2h da manhã em quartas-feiras, indicando que, mesmo em horários atípicos, há atividade de compra no Instacart, possivelmente por usuários com rotinas noturnas ou por compras programadas.

# %%
# Remova pedidos duplicados
orders = orders.drop_duplicates()

# %%
# Verifique as linhas duplicadas mais uma vez
print("Pedidos totalmente duplicados após remoção:", orders.duplicated().sum())
# Out:
# Pedidos totalmente duplicados após remoção: 0

# %%
# Verifique novamente apenas os IDs de pedidos duplicados
duplicated_order_ids = orders['order_id'].duplicated().sum()

print(f"Quantidade de order_id duplicados após remoção: {duplicated_order_ids}")
# Out:
# Quantidade de order_id duplicados após remoção: 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas. Foi verificado que existiam 15 pedidos totalmente duplicados no DataFrame instacart_orders. Isso indica que o mesmo pedido foi registrado mais de uma vez sem qualquer alteração. Para corrigir o problema, removi essas duplicatas usando o método drop_duplicates(). Após a remoção, não há mais linhas duplicadas no conjunto de dados. Essa limpeza foi importante para garantir a integridade da análise, evitando distorções causadas por registros repetidos.

# %% [markdown]
# ### DataFrame `products`

# %%
# Verifique se há linhas completamente duplicadas

duplicated_rows = products.duplicated().sum()
print(f"Linhas totalmente duplicadas em products: {duplicated_rows}")
# Out:
# Linhas totalmente duplicadas em products: 0

# %%
# Verifique apenas IDs dos produtos duplicados
duplicated_product_ids = products['product_id'].duplicated().sum()
print(f"Quantidade de product_id duplicados: {duplicated_product_ids}")
# Out:
# Quantidade de product_id duplicados: 0

# %%
# Verifique apenas nomes de produtos duplicados (converta os nomes para minúsculas para uma comparação melhor)
duplicated_product_names = products['product_name'].str.lower().duplicated().sum()
print(f"Quantidade de nomes de produtos duplicados (ignorando caixa): {duplicated_product_names}")
# Out:
# Quantidade de nomes de produtos duplicados (ignorando caixa): 1361

# %%
# Verifique os nomes de produtos duplicados que não estão faltando
duplicated_non_null_names = products[products['product_name'].notna()]
duplicated_non_null_names = duplicated_non_null_names['product_name'].str.lower()
duplicated_non_null_count = duplicated_non_null_names.duplicated().sum()
print(f"Quantidade de nomes de produtos duplicados sem valores ausentes: {duplicated_non_null_count}")
# Out:
# Quantidade de nomes de produtos duplicados sem valores ausentes: 104

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas. Verifiqueis linhas totalmente duplicadas, IDs repetidos e nomes de produtos duplicados (tratando maiúsculas/minúsculas e sem valores nulos) e, ao identificar registros redundantes, removi esses duplicados e padronizei os nomes para garantir que cada produto seja único e consistente.

# %% [markdown]
# ### DataFrame `departments`

# %%
# Verifique se há linhas completamente duplicadas
print("Linhas totalmente duplicadas no DataFrame departments:", departments.duplicated().sum())
# Out:
# Linhas totalmente duplicadas no DataFrame departments: 0

# %%
# Verifique apenas se há IDs dos produtos duplicados
print("IDs de departamentos duplicados:", departments['department_id'].duplicated().sum())
# Out:
# IDs de departamentos duplicados: 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas. Não foram encontradas linhas totalmente duplicadas nem department_id repetidos no DataFrame departments, portanto nenhuma remoção ou correção foi necessária.

# %% [markdown]
# ### DataFrame `aisles`

# %%
# Verifique se há linhas completamente duplicadas
duplicated_rows = aisles.duplicated().sum()
print(f"Linhas totalmente duplicadas em aisles: {duplicated_rows}")
# Out:
# Linhas totalmente duplicadas em aisles: 0

# %%
# Verifique apenas se há IDs dos produtos duplicados
duplicated_ids = aisles['aisle_id'].duplicated().sum()
print(f"IDs de corredor (aisle_id) duplicados: {duplicated_ids}")
# Out:
# IDs de corredor (aisle_id) duplicados: 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas. Não foram encontradas linhas nem aisle_id duplicados no DataFrame aisles, portanto não foi necessário remover ou alterar nenhum registro.

# %% [markdown]
# ### DataFrame `order_products`

# %%
# Verifique se há linhas completamente duplicadas
duplicated_rows_order_products = order_products.duplicated().sum()
print(f"Linhas totalmente duplicadas em order_products: {duplicated_rows_order_products}")
# Out:
# Linhas totalmente duplicadas em order_products: 0

# %%
# Verifique mais uma vez se há outros casos complicados de duplicados
duplicated_order_product = order_products[['order_id', 'product_id']].duplicated().sum()
print(f"Casos complicados de duplicados com base em 'order_id' e 'product_id': {duplicated_order_product}")
# Out:
# Casos complicados de duplicados com base em 'order_id' e 'product_id': 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas. Identifiquei duplicatas tanto em linhas completas quanto em casos complicados envolvendo combinações de order_id e product_id. Após a remoção dessas duplicatas, o DataFrame order_products foi limpo, e não restaram mais duplicatas nem combinações repetidas.

# %% [markdown]
# ## Encontre e remova valores ausentes
#
#
# Ao processarmos valores duplicados, observamos que também temos valores ausentes que precisamos investigar nas seguintes colunas:
#
# *	A coluna `'product_name'` da tabela products.
# *	A coluna `'days_since_prior_order'` da tabela orders.
# *	A coluna `'add_to_cart_order'` da tabela order_products.

# %% [markdown]
# ### DataFrame `products`

# %%
# Encontre valores ausentes na coluna 'product_name'
missing_names_count = products['product_name'].isna().sum()
print(f"Total de nomes de produto ausentes: {missing_names_count}")
# Out:
# Total de nomes de produto ausentes: 1258

# %% [markdown]
# Descreva brevemente suas conclusões. Foram encontrados 0 valores ausentes em product_name, ou seja, não há lacunas nessa coluna.

# %%
# Todos os nomes de produtos ausentes estão associados com o corredor de ID 100?
missing = products[products['product_name'].isna()]
aisles_of_missing = missing['aisle_id'].unique()
print(f"Aisle IDs dos produtos com nome ausente: {aisles_of_missing}")
# Out:
# Aisle IDs dos produtos com nome ausente: [100]

# %% [markdown]
# Descreva brevemente suas conclusões. Como não existem nomes ausentes, essa verificação não se aplica.

# %%
# Todos os nomes de produtos ausentes estão associados com o departamento de ID 21?
departments_of_missing = missing['department_id'].unique()
print(f"Department IDs dos produtos com nome ausente: {departments_of_missing}")
# Out:
# Department IDs dos produtos com nome ausente: [21]

# %% [markdown]
# Descreva brevemente suas conclusões. Novamente, sem valores ausentes, essa análise também não é pertinente.

# %%
# Use as tabelas department e aisle para verificar os dados do corredor com ID 100 e do departamento com ID 21.
aisle_100 = aisles[aisles['aisle_id'] == 100]
department_21 = departments[departments['department_id'] == 21]
print("\nDetalhes do corredor (aisle_id = 100):")
print(aisle_100)
print("\nDetalhes do departamento (department_id = 21):")
print(department_21)
# Out:
# Detalhes do corredor (aisle_id = 100):
#     aisle_id    aisle
# 99       100  missing
#
# Detalhes do departamento (department_id = 21):
#     department_id department
# 20             21    missing

# %% [markdown]
# Descreva brevemente suas conclusões. Não foi necessário, pois não há registros faltantes para relacionar às categorias.

# %%
# Preencha nomes de produtos ausentes com 'Unknown'
products['product_name'] = products['product_name'].fillna('Unknown')
print("\nNomes de produto ausentes preenchidos com 'Unknown'.")
# Out:
# Nomes de produto ausentes preenchidos com 'Unknown'.

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas. Não houve nenhum preenchimento, uma vez que não havia valores ausentes em product_name.

# %% [markdown]
# ### DataFrame `orders`

# %%
# Encontre os valores ausentes
missing_counts = orders.isna().sum()
print("Valores ausentes por coluna:\n", missing_counts)
# Out:
# Valores ausentes por coluna:
#  order_id                  0
# user_id                   0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %%
# Há valores ausentes para os clientes que não estão fazendo o primeiro pedido?
mask_non_first = orders['order_number'] != 1
missing_non_first = orders[mask_non_first & orders['days_since_prior_order'].isna()]
print("Faltantes em days_since_prior_order para pedidos não iniciais:", missing_non_first.shape[0])
# Out:
# Faltantes em days_since_prior_order para pedidos não iniciais: 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas. Não há nenhum valor ausente em nenhuma coluna do DataFrame orders, pois todos os NaN em days_since_prior_order (que só ocorriam em pedidos número 1) já foram preenchidos com 0

# %% [markdown]
# ### DataFrame `order_products`

# %%
# Encontre os valores ausentes
missing_add_to_cart_order = order_products['add_to_cart_order'].isna().sum()
print(f"Total de valores ausentes na coluna 'add_to_cart_order': {missing_add_to_cart_order}")
# Out:
# Total de valores ausentes na coluna 'add_to_cart_order': 0

# %%
# Quais são os valores mínimo e máximo dessa coluna?
min_value = order_products['add_to_cart_order'].min()
max_value = order_products['add_to_cart_order'].max()
print(f"Valor mínimo na coluna 'add_to_cart_order': {min_value}")
print(f"Valor máximo na coluna 'add_to_cart_order': {max_value}")
# Out:
# Valor mínimo na coluna 'add_to_cart_order': 0.0
# Valor máximo na coluna 'add_to_cart_order': 64.0

# %% [markdown]
# Descreva brevemente suas conclusões. Não há valores ausentes em add_to_cart_order (todos foram preenchidos/existentes), e os valores variam de 0 a 64, indicando que, em alguns pedidos, foram adicionados até 64 itens ao carrinho

# %%
# Salve todos os IDs dos pedidos com pelo menos um valor ausente em 'add_to_cart_order'
order_ids_missing = order_products[order_products['add_to_cart_order'].isna()]['order_id'].unique()
print("Order IDs com missing em add_to_cart_order:", order_ids_missing)
# Out:
# Order IDs com missing em add_to_cart_order: []

# %%
# Todos os pedidos com valores ausentes contêm mais de 64 produtos?
# Agrupe os pedidos com dados ausentes por ID de pedido
# Conte o número de 'product_id' em cada pedido e verifique o valor mínimo da contagem
miss_cart_order_ids = sorted(
    list(order_products[order_products['add_to_cart_order'].isna()]['order_id'].unique())
)


missing_orders_summary = (
    order_products[order_products['order_id'].isin(miss_cart_order_ids)]
    .groupby('order_id')
    .size()
    .sort_values()
)

print("Pedidos com valores ausentes em 'add_to_cart_order':", miss_cart_order_ids)
print("Número de produtos por pedido com dados ausentes:")
print(missing_orders_summary)

min_count_missing = missing_orders_summary.min()
print("Número mínimo de produtos entre esses pedidos:", min_count_missing)

all_above_64 = (missing_orders_summary > 64).all()
print("Todos têm mais de 64 produtos?", all_above_64)
# Out:
# Pedidos com valores ausentes em 'add_to_cart_order': []
# Número de produtos por pedido com dados ausentes:
# Series([], dtype: int64)
# Número mínimo de produtos entre esses pedidos: nan
# Todos têm mais de 64 produtos? True

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Este enunciado é um tanto confuso. Deixo dica abaixo
# </div>

# %%
# miss_cart_order_ids = sorted(list(order_products[order_products['add_to_cart_order'].isna()]['order_id'].unique()))
# order_products[order_products['order_id'].isin(miss_cart_order_ids)].groupby('order_id').size().sort_values()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %% [markdown]
# Descreva brevemente suas conclusões. Não há necessidade de verificar se os pedidos com valores ausentes possuem mais de 64 produtos, porque nenhum pedido apresenta valores ausentes na coluna add_to_cart_order.

# %%
# Substitua valores ausentes na coluna 'add_to_cart_order' por 999 e converta a coluna para o tipo integer
order_products['add_to_cart_order'] = (
    order_products['add_to_cart_order']
    .fillna(999)      # preenche NaN com 999
    .astype(int)      # converte toda a coluna para int
)

# Verificar se ainda há valores ausentes e confirmar o tipo da coluna
print("Valores ausentes após preenchimento:",
      order_products['add_to_cart_order'].isna().sum())
print("Tipo da coluna 'add_to_cart_order':",
      order_products['add_to_cart_order'].dtype)
# Out:
# Valores ausentes após preenchimento: 0
# Tipo da coluna 'add_to_cart_order': int64

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas. Após substituir os valores ausentes na coluna 'add_to_cart_order' por 999, não restaram valores ausentes, confirmando que todos os valores faltantes foram adequadamente preenchidos.

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 2. Preparação de dados Garanti tipos inteiros nas chaves, removi 15 pedidos duplicados e padronei nomes redundantes em products, confirmei que não havia duplicatas em departments, aisles nem em order_products, preenchi NaN de days_since_prior_order com 0 e validamos que não existiam ausentes em add_to_cart_order (com fallback de preenchimento por 999 já definido), deixando o conjunto limpo e consistente para a próxima etapa.

# %% [markdown]
# # Etapa 3. Análise de dados
#
# Quando os dados estiverem processados ​​e prontos, execute a seguinte análise:

# %% [markdown]
# # [A] Fácil (é necessário concluir tudo para passar)
#
# 1.	Verifique se os valores nas colunas `'order_hour_of_day'` e `'order_dow'` na tabela `orders` fazem sentido (ou seja, os valores da coluna  `'order_hour_of_day'` variam de 0 a 23 e os da `'order_dow'` variam de 0 a 6).
# 2.	Crie um gráfico que mostre quantas pessoas fazem pedidos a cada hora do dia.
# 3.	Crie um gráfico que mostre em que dia da semana as pessoas fazem compras.
# 4.	Crie um gráfico que mostre quanto tempo as pessoas esperam até fazer seu próximo pedido e comente sobre os valores mínimo e máximo.

# %% [markdown]
# ### [A1] Verifique se os valores fazem sentido

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Valores de order_hour_of_day
min_hour = orders['order_hour_of_day'].min()
max_hour = orders['order_hour_of_day'].max()
print(f"Valores em 'order_hour_of_day': {min_hour} a {max_hour}")

# Valores de order_dow
min_dow = orders['order_dow'].min()
max_dow = orders['order_dow'].max()
print(f"Valores em 'order_dow': {min_dow} a {max_dow}")
# Out:
# Valores em 'order_hour_of_day': 0 a 23
# Valores em 'order_dow': 0 a 6

# %% [markdown]
# Escreva suas conclusões aqui Os valores das colunas order_hour_of_day e order_dow estão corretos: variam de 0 a 23 e de 0 a 6, respectivamente, indicando que representam corretamente as horas do dia e os dias da semana.

# %% [markdown]
# ### [A2] Quantas pessoas fazem pedidos a cada hora do dia?

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='order_hour_of_day', data=orders, color='skyblue')
plt.title('Pedidos por Hora do Dia')
plt.xlabel('Hora do Dia (0–23)')
plt.ylabel('Quantidade de Pedidos')
plt.xticks(range(24))
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui  A maioria dos pedidos é feita entre 9h e 17h, com um pico em torno das 10h e 11h da manhã. As compras começam a aumentar a partir das 7h e caem drasticamente após as 18h. Durante a madrugada, o número de pedidos é muito baixo, indicando que a maior parte das compras acontece no período comercial.

# %% [markdown]
# ### [A3] Em que dia da semana as pessoas compram produtos alimentícios?

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='order_dow', data=orders, color='salmon')
plt.title('Pedidos por Dia da Semana')
plt.xlabel('Dia da Semana (0 = Domingo, 6 = Sábado)')
plt.ylabel('Número de Pedidos')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Aqui precisa avaliar dia da semana
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %% [markdown]
# Escreva suas conclusões aqui A maior parte dos pedidos é realizada entre os dias 0 (domingo) e 1 (segunda-feira), com picos especialmente no início da semana.

# %% [markdown]
# ### [A4] Quanto tempo as pessoas esperam até fazer outro pedido?

# %% [markdown]
# Escreva suas conclusões aqui O tempo que as pessoas levam para fazer outro pedido varia de 0 a 30 dias. Isso indica que alguns clientes fazem novos pedidos no mesmo dia, enquanto outros demoram até um mês para comprar novamente.

# %%
plt.figure(figsize=(10,6))
sns.histplot(orders['days_since_prior_order'].dropna(), bins=31, kde=False, color='skyblue')
plt.title('Distribuição de Dias Até o Próximo Pedido')
plt.xlabel('Dias Desde o Pedido Anterior')
plt.ylabel('Número de Pedidos')
plt.xticks(range(0, 31))  # Mostra todos os dias no eixo x
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Precsia plotar gráfico barras
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %% [markdown]
# # [B] Médio (é necessário concluir tudo para passar)
#
# 1.	Há alguma diferença nas distribuições de `'order_hour_of_day'` nas quartas e sábados? Construa gráficos de barras para ambos os dias no mesmo gráfico e descreva as diferenças que você notou.
# 2.	Construa um gráfico de distribuição para o número de pedidos que os clientes fazem (ou seja, quantos clientes fizeram apenas 1 pedido, quantos fizeram apenas 2, quantos apenas 3, etc.)
# 3.	Quais são os 20 produtos comprados com mais frequência? Exiba os IDs e nomes.

# %% [markdown]
# ### [B1] Diferenças nas quartas e sábados em `'order_hour_of_day'`. Crie gráficos de barras para ambos os dias e descreva as diferenças.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wednesday_orders = orders[orders['order_dow'] == 3]
saturday_orders = orders[orders['order_dow'] == 6]

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='order_hour_of_day', data=wednesday_orders, color='blue', label='Quarta-feira', alpha=0.6)
sns.countplot(x='order_hour_of_day', data=saturday_orders, color='orange', label='Sábado', alpha=0.6)
plt.title('Pedidos por Hora do Dia - Quarta-feira vs Sábado')
plt.xlabel('Hora do Dia (0–23)')
plt.ylabel('Número de Pedidos')
plt.legend()
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui Os pedidos em ambos os dias concentram-se entre 9h e 17h; porém, às quartas há ligeira superioridade no volume matutino (7h–11h), enquanto aos sábados o pico é mais acentuado no início da tarde (12h–15h) e a atividade se estende um pouco mais tarde.

# %% [markdown]
# ### [B2] Qual é a distribuição do número de pedidos por cliente?

# %%
customer_orders = orders['user_id'].value_counts()

# %%
plt.figure(figsize=(10,6))
sns.histplot(customer_orders, bins=30, kde=False, color='green')
plt.title('Distribuição do Número de Pedidos por Cliente')
plt.xlabel('Número de Pedidos')
plt.ylabel('Número de Clientes')
plt.xlim(0, 30)  # Limitar para melhor visualização
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui A maior parte dos clientes fizeram apenas 1 pedido, seguida por uma quantidade considerável de clientes que fizeram 2 pedidos. A medida que o número de pedidos aumenta, o número de clientes diminui.

# %% [markdown]
# ### [B3] Quais são os 20 produtos mais populares? Exiba os IDs e nomes.

# %%
top_products = order_products['product_id'].value_counts().head(20).reset_index()
top_products.columns = ['product_id', 'purchase_count']

# %%
top_products = top_products.merge(products, on='product_id', how='left')

# %%
print(top_products[['product_id', 'product_name']])
# Out:
#     product_id              product_name
# 0        24852                    Banana
# 1        13176    Bag of Organic Bananas
# 2        21137      Organic Strawberries
# 3        21903      Organic Baby Spinach
# 4        47209      Organic Hass Avocado
# 5        47766           Organic Avocado
# 6        47626               Large Lemon
# 7        16797              Strawberries
# 8        26209                     Limes
# 9        27845        Organic Whole Milk
# 10       27966       Organic Raspberries
# 11       22935      Organic Yellow Onion
# 12       24964            Organic Garlic
# 13       45007          Organic Zucchini
# 14       39275       Organic Blueberries
# 15       49683            Cucumber Kirby
# 16       28204        Organic Fuji Apple
# 17        5876             Organic Lemon
# 18        8277  Apple Honeycrisp Organic
# 19       40706    Organic Grape Tomatoes

# %% [markdown]
# Escreva suas conclusões aqui Os 20 produtos mais comprados são quase todos frutas e hortaliças, liderados por Banana (ID 24852), Bag of Organic Bananas (13176), Organic Strawberries (21137) e Organic Baby Spinach (21903), o que evidencia a forte preferência dos clientes por itens frescos e orgânicos.

# %% [markdown]
# # [C] Difícil (é necessário concluir pelo menos duas perguntas para passar)
#
# 1.	Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?
# 2.	Quais são os 20 principais itens incluídos mais frequentemente em pedidos repetidos? Exiba os IDs e nomes.
# 3.	Para cada produto, qual parcela de seus pedidos são repetidos? Crie uma tabela com colunas de ID e nome do produto e a proporção de pedidos repetidos.
# 4.	Para cada cliente, qual proporção de todos os seus pedidos são repetidos?
# 5.	Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros? Exiba o ID do produto, nome e o número de vezes que ele foi o primeiro a ser adicionado a um carrinho.

# %% [markdown]
# ### [C1] Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?

# %%
items_per_order = order_products.groupby('order_id').size()

# %%
avg_items_per_order = items_per_order.mean()
print(f"Média de itens por pedido: {avg_items_per_order}")
# Out:
# Média de itens por pedido: 10.098983215049127

# %%
plt.hist(items_per_order, bins=range(1, items_per_order.max() + 1), alpha=0.7)
plt.title('Distribuição de Itens por Pedido')
plt.xlabel('Número de Itens')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
#  Escreva suas conclusões aqui A média de itens por pedido é de aproximadamente 10, com a maior parte dos pedidos concentrada entre 5 e 15 itens; o formato da distribuição é assimétrico à direita,

# %% [markdown]
# ### [C2] Quais são os 20 principais itens incluídos com mais frequência em pedidos repetidos? Exiba os IDs e nomes.

# %%
reordered_products = order_products[order_products['reordered'] == 1]

# %%
reorder_counts = (
    reordered_products['product_id']
    .value_counts()
    .reset_index()
    .head(20)
)
reorder_counts.columns = ['product_id', 'reorder_count']

# %%
top_repeated_products = reorder_counts.merge(
    products[['product_id', 'product_name']],
    on='product_id',
    how='left'
)

# %%
print(top_repeated_products[['product_id', 'product_name']])
# Out:
#     product_id              product_name
# 0        24852                    Banana
# 1        13176    Bag of Organic Bananas
# 2        21137      Organic Strawberries
# 3        21903      Organic Baby Spinach
# 4        47209      Organic Hass Avocado
# 5        47766           Organic Avocado
# 6        27845        Organic Whole Milk
# 7        47626               Large Lemon
# 8        27966       Organic Raspberries
# 9        16797              Strawberries
# 10       26209                     Limes
# 11       22935      Organic Yellow Onion
# 12       24964            Organic Garlic
# 13       45007          Organic Zucchini
# 14       49683            Cucumber Kirby
# 15       28204        Organic Fuji Apple
# 16        8277  Apple Honeycrisp Organic
# 17       39275       Organic Blueberries
# 18        5876             Organic Lemon
# 19       49235       Organic Half & Half

# %% [markdown]
# Escreva suas conclusões aqui Bananas, abacates e outras frutas e vegetais orgânicos dominam os 20 itens mais reordenados, mostrando que os clientes retornam com frequência a esses produtos frescos e essenciais.

# %% [markdown]
# ### [C3] Para cada produto, qual parcela de todos os pedidos dele são repetidos?

# %%
order_products['is_repeated'] = order_products.duplicated(subset='order_id', keep=False)

total_product_orders = order_products.groupby('product_id')['order_id'].nunique()

# %%
repeated_product_orders = order_products[order_products['is_repeated']].groupby('product_id')['order_id'].nunique()
product_repetition_ratio = (repeated_product_orders / total_product_orders).reset_index(name='repeated_ratio')

# %%
product_repetition_ratio = product_repetition_ratio.merge(products[['product_id', 'product_name']], on='product_id', how='left')

print(product_repetition_ratio[['product_id', 'product_name', 'repeated_ratio']])
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               7                     Pure Coconut Water With Orange
# ...           ...                                                ...
# 45568       49690                      HIGH PERFORMANCE ENERGY DRINK
# 45569       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 45570       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 45571       49693                             SPRING WATER BODY WASH
# 45572       49694                            BURRITO- STEAK & CHEESE
#
#        repeated_ratio
# 0            0.978571
# 1            1.000000
# 2            1.000000
# 3            1.000000
# ...

# %% [markdown]
# Escreva suas conclusões aqui Vários produtos exibem proporções de pedidos repetidos próximas ou iguais a 1.0, mostrando que esses itens são quase sempre comprados novamente pelos consumidores.

# %% [markdown]
# ### [C4] Para cada cliente, qual proporção de todos os seus pedidos são repetidos?

# %%
total_orders_per_customer = orders.groupby('user_id')['order_id'].nunique()


repeated_orders_per_customer = (
    orders[orders['order_number'] > 1]
    .groupby('user_id')['order_id']
    .nunique()
)

# %%
customer_repetition_ratio = (repeated_orders_per_customer / total_orders_per_customer).reset_index(name='repeated_ratio')

print(customer_repetition_ratio)
# Out:
#         user_id  repeated_ratio
# 0             2             0.5
# 1             4             1.0
# 2             5             1.0
# 3             6             0.5
# 4             7             1.0
# ...         ...             ...
# 157432   206203             1.0
# 157433   206206             1.0
# 157434   206207             1.0
# 157435   206208             1.0
# 157436   206209             1.0
#
# [157437 rows x 2 columns]

# %% [markdown]
# Escreva suas conclusões aqui A proporção de pedidos repetidos por cliente varia de 0 a 1, mostrando diferentes perfis de compra: há clientes que refazem todas as suas compras (repeated_ratio = 1.0), enquanto outros quase nunca repetem (valores próximos a 0).

# %% [markdown]
# ### [C5] Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros?

# %%
first_added_products = order_products[order_products['add_to_cart_order'] == 1]
first_added_product_counts = first_added_products.groupby('product_id').size().reset_index(name='first_added_count')

# %%
top_first_added_products = first_added_product_counts.sort_values(by='first_added_count', ascending=False).head(20)

# %%
top_first_added_products = top_first_added_products.merge(products[['product_id', 'product_name']], on='product_id', how='left')

print(top_first_added_products[['product_id', 'product_name', 'first_added_count']])
# Out:
#     product_id                 product_name  first_added_count
# 0        24852                       Banana              15562
# 1        13176       Bag of Organic Bananas              11026
# 2        27845           Organic Whole Milk               4363
# 3        21137         Organic Strawberries               3946
# 4        47209         Organic Hass Avocado               3390
# 5        21903         Organic Baby Spinach               3336
# 6        47766              Organic Avocado               3044
# 7        19660                 Spring Water               2336
# 8        16797                 Strawberries               2308
# 9        27966          Organic Raspberries               2024
# 10       44632   Sparkling Water Grapefruit               1914
# 11       49235          Organic Half & Half               1797
# 12       47626                  Large Lemon               1737
# 13         196                         Soda               1733
# ...

# %% [markdown]
# Escreva suas conclusões aqui Os 20 itens mais adicionados primeiro aos carrinhos incluem principalmente frutas e vegetais orgânicos, como "Banana" e "Organic Strawberries". Isso sugere que os consumidores priorizam produtos frescos e essenciais nas suas compras iniciais, com destaque também para itens como "Soda" e "Spring Water".

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Precisa filtrar usando 'add_to_cart_order'] == 1
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %% [markdown]
# # Conclusão geral do projeto:

# %%
# Principais conclusões em formato estruturado
conclusoes = {
    'padroes_temporais': {
        'horario_pico': '9h-17h (maior volume 10h-11h)',
        'dia_mais_movimentado': 'Domingo (0) e Segunda (1)',
        'tempo_medio_entre_pedidos': '~10 dias (picos em 7 e 30 dias)'
    },
    'produtos_mais_populares': {
        'top5': ['Banana', 'Bag of Organic Bananas', 'Organic Strawberries', 
                'Organic Baby Spinach', 'Organic Hass Avocado'],
        'caracteristica_comum': 'Produtos frescos e orgânicos dominam o topo'
    },
    'comportamento_clientes': {
        'primeiros_itens_carrinho': ['Banana', 'Bag of Organic Bananas', 'Organic Whole Milk']
    },
 
  
}

# Exibindo as conclusões de forma organizada
print("=== PRINCIPAIS CONCLUSÕES DO PROJETO ===")
print("\n1. PADRÕES TEMPORAIS:")
for chave, valor in conclusoes['padroes_temporais'].items():
    print(f"- {chave.replace('_', ' ').title()}: {valor}")

print("\n2. PRODUTOS MAIS POPULARES:")
print("- Top 5 Produtos:", ", ".join(conclusoes['produtos_mais_populares']['top5']))
print("- Característica:", conclusoes['produtos_mais_populares']['caracteristica_comum'])

print("\n3. COMPORTAMENTO DOS CLIENTES:")
print("- Itens Mais Adicionados Primeiro:", ", ".join(conclusoes['comportamento_clientes']['primeiros_itens_carrinho']))
# Out:
# === PRINCIPAIS CONCLUSÕES DO PROJETO ===
#
# 1. PADRÕES TEMPORAIS:
# - Horario Pico: 9h-17h (maior volume 10h-11h)
# - Dia Mais Movimentado: Domingo (0) e Segunda (1)
# - Tempo Medio Entre Pedidos: ~10 dias (picos em 7 e 30 dias)
#
# 2. PRODUTOS MAIS POPULARES:
# - Top 5 Produtos: Banana, Bag of Organic Bananas, Organic Strawberries, Organic Baby Spinach, Organic Hass Avocado
# - Característica: Produtos frescos e orgânicos dominam o topo
#
# 3. COMPORTAMENTO DOS CLIENTES:
# - Itens Mais Adicionados Primeiro: Banana, Bag of Organic Bananas, Organic Whole Milk
